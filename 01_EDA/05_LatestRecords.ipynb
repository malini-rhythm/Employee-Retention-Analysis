# %% [markdown]
# Optimizing Rows | Considering Latest Records only

# %%
import pandas as pd

# %%
df = pd.read_csv('../00_Data/data.csv')
df.head()
# Out:
#   Salary Date Salary Month       Salary ID Salary Status  Employee ID  \
# 0  2011-05-15      2011-05  100001_2011-05        Active       100001
# 1  2011-05-15      2011-05  100002_2011-05        Active       100002
# 2  2011-05-15      2011-05  100003_2011-05        Active       100003
# 3  2011-05-15      2011-05  100004_2011-05        Active       100004
# 4  2011-06-12      2011-06  100001_2011-06        Active       100001
#
#   Employee Name  Gender   Generation  Joining Termination  ...  \
# 0   Name_100001    Male        Gen X  2001-07         NaN  ...
# 1   Name_100002    Male        Gen X  2001-09         NaN  ...
# 2   Name_100003  Female        Gen X  2008-08         NaN  ...
# 3   Name_100004  Female  Millennials  2008-07         NaN  ...
# 4   Name_100001    Male        Gen X  2001-07         NaN  ...
#
#   Term Sub Reason Employee Grade   Location Career Bucket Age Bucket  \
# 0             NaN         Senior  Bengaluru      Above 35   41 T0 45
# ...

# %%
df.shape
# Out:
# (78377, 22)

# %%
df.loc[df['Employee ID'] == 100001]
# Out:
#       Salary Date Salary Month       Salary ID Salary Status  Employee ID  \
# 0      2011-05-15      2011-05  100001_2011-05        Active       100001
# 4      2011-06-12      2011-06  100001_2011-06        Active       100001
# 7      2011-07-15      2011-07  100001_2011-07        Active       100001
# 10     2011-08-14      2011-08  100001_2011-08        Active       100001
# 14     2011-09-15      2011-09  100001_2011-09        Active       100001
# 18     2011-10-15      2011-10  100001_2011-10        Active       100001
# 22     2011-11-15      2011-11  100001_2011-11        Active       100001
# 28     2011-12-15      2011-12  100001_2011-12        Active       100001
# 21821  2012-01-14      2012-01  100001_2012-01        Active       100001
# 21900  2012-02-15      2012-02  100001_2012-02        Active       100001
# 21980  2012-03-15      2012-03  100001_2012-03        Active       100001
# 22060  2012-04-15      2012-04  100001_2012-04        Active       100001
# ...

# %%
df.dtypes
# Out:
# Salary Date        object
# Salary Month       object
# Salary ID          object
# Salary Status      object
# Employee ID         int64
# Employee Name      object
# Gender             object
# Generation         object
# Joining            object
# Termination        object
# Term Category      object
# Term Reason        object
# Term Sub Reason    object
# Employee Grade     object
# Location           object
# Career Bucket      object
# Age Bucket         object
# Manager ID          int64
# Manager Name       object
# Performance        object
# Talent             object
# Department         object
# dtype: object

# %%
df['Salary Date'] = pd.to_datetime(df['Salary Date'])
df.dtypes
# Out:
# Salary Date        datetime64[ns]
# Salary Month               object
# Salary ID                  object
# Salary Status              object
# Employee ID                 int64
# Employee Name              object
# Gender                     object
# Generation                 object
# Joining                    object
# Termination                object
# Term Category              object
# Term Reason                object
# Term Sub Reason            object
# Employee Grade             object
# Location                   object
# Career Bucket              object
# Age Bucket                 object
# Manager ID                  int64
# Manager Name               object
# Performance                object
# Talent                     object
# Department                 object
# dtype: object

# %%
df_latest = df.loc[df['Salary Date'] == df.groupby('Employee ID')['Salary Date'].transform('max')]
df_latest
# Out:
#       Salary Date Salary Month       Salary ID Salary Status  Employee ID  \
# 3      2011-05-15      2011-05  100004_2011-05        Active       100004
# 200    2011-05-15      2011-05  100019_2011-05      Inactive       100019
# 318    2011-05-15      2011-05  100020_2011-05      Inactive       100020
# 356    2013-12-15      2013-12  100018_2013-12        Active       100018
# 498    2011-10-15      2011-10  100035_2011-10        Active       100035
# ...           ...          ...             ...           ...          ...
# 78372  2016-10-15      2016-10  102284_2016-10        Active       102284
# 78373  2016-10-15      2016-10  102281_2016-10        Active       102281
# 78374  2016-10-15      2016-10  102282_2016-10        Active       102282
# 78375  2016-10-15      2016-10  102283_2016-10        Active       102283
# 78376  2016-10-15      2016-10  100299_2016-10        Active       100299
#
#       Employee Name  Gender   Generation  Joining Termination  ...  \
# ...

# %%
df_latest.shape
# Out:
# (2285, 22)

# %%
df_latest.to_csv('../00_Data/01_LatestRecords.csv', index=False)
