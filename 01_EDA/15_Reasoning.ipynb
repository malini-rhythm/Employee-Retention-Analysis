# %% [markdown]
# Resignation Reasoning

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

from itertools import combinations

# %%
df = pd.read_csv('../00_Data/04_NoOutliers.csv')
df.head()
# Out:
#    Gender   Generation  Term Sub Reason Employee Grade   Location  \
# 0  Female  Millennials    Career Growth         Junior  Bengaluru
# 1  Female  Millennials    Career Growth            Mid  Bengaluru
# 2    Male  Millennials    Career Growth         Junior  Bengaluru
# 3    Male        Gen X    Career Growth         Senior  Bengaluru
# 4    Male  Millennials  Personal Reason            Mid  Bengaluru
#
#   Career Bucket Age Bucket  Manager ID Talent Department  active_months
# 0      Below 30   26 To 30      102292    NaN         AC           59.0
# 1      31 to 35   26 To 30      100411    NaN         AD            4.0
# 2      Below 30   26 To 30      102304    NaN         AG           26.0
# 3      Above 35   36 T0 40      102324    NaN         AI          126.0
# 4      31 to 35   31 To 35      100619    NaN         AI          126.0

# %%
df['Reason'] = df['Term Sub Reason'].copy()
df.drop(columns=['Term Sub Reason'], inplace=True)
df.head()
# Out:
#    Gender   Generation Employee Grade   Location Career Bucket Age Bucket  \
# 0  Female  Millennials         Junior  Bengaluru      Below 30   26 To 30
# 1  Female  Millennials            Mid  Bengaluru      31 to 35   26 To 30
# 2    Male  Millennials         Junior  Bengaluru      Below 30   26 To 30
# 3    Male        Gen X         Senior  Bengaluru      Above 35   36 T0 40
# 4    Male  Millennials            Mid  Bengaluru      31 to 35   31 To 35
#
#    Manager ID Talent Department  active_months           Reason
# 0      102292    NaN         AC           59.0    Career Growth
# 1      100411    NaN         AD            4.0    Career Growth
# 2      102304    NaN         AG           26.0    Career Growth
# 3      102324    NaN         AI          126.0    Career Growth
# 4      100619    NaN         AI          126.0  Personal Reason

# %%
def binary_encoding(df:pd.DataFrame, column:str, true_value:str):
    """Binary Encoding"""

    unique_values = df[column].unique()

    for val in unique_values:
        if val == true_value:
            df.loc[:, column] = df[column].replace(val, '1').infer_objects(copy=False)
        else:
            df.loc[:, column] = df[column].replace(val, '0').infer_objects(copy=False)

    df[column] = pd.to_numeric(df[column])

    return df

# %%
# Label Encoding - If values are not in order
def label_encoding(df:pd.DataFrame, columns:list):
    """Label Encoding Function"""

    le = LabelEncoder()
    for column in columns:
        df[column] = le.fit_transform(df[column])
        df[column] = df[column] + 1
        df[column] = pd.to_numeric(df[column])
    
    return df

# %%
def ordinal_encoding(df:pd.DataFrame, column:str, order_list:list):
    """Encoding Ordered Data"""

    data = df.copy()
    count = 1
    for item in order_list:
        data[column] = data[column].replace(item, f'{count}')
        count = count +1 

    data[column] = pd.to_numeric(data[column])
    return data

# %% [markdown]
# Apply Encodings

# %%
df = binary_encoding(df, 'Gender', 'Female')

label_cols = ['Location', 'Talent', 'Department']
df = label_encoding(df, label_cols)

gen_list = ['Gen Z', 'Millennials', 'Gen X', 'Baby Boomers']
df = ordinal_encoding(df, 'Generation', gen_list)

emp_grade = ['Junior', 'Mid', 'Senior']
df = ordinal_encoding(df, 'Employee Grade', emp_grade)

career_bucket = ['Below 30', '31 to 35', 'Above 35']
df = ordinal_encoding(df, 'Career Bucket', career_bucket)

order_list = ['21 To 25', '26 To 30', '31 To 35', '36 T0 40',  '41 T0 45', '46 T0 50', '51 T0 55']
df = ordinal_encoding(df, 'Age Bucket', order_list)
df.head()
# Out:
#    Gender  Generation  Employee Grade  Location  Career Bucket  Age Bucket  \
# 0       1           2               1         1              1           2
# 1       1           2               2         1              2           2
# 2       0           2               1         1              1           2
# 3       0           3               3         1              3           4
# 4       0           2               2         1              2           3
#
#    Manager ID  Talent  Department  active_months           Reason
# 0      102292       5           2           59.0    Career Growth
# 1      100411       5           3            4.0    Career Growth
# 2      102304       5           5           26.0    Career Growth
# 3      102324       5           7          126.0    Career Growth
# 4      100619       5           7          126.0  Personal Reason

# %% [markdown]
# Drop Correlated Features

# %%
df.drop(['Career Bucket', 'Generation', 'Employee Grade'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Gender  Location  Age Bucket  Manager ID  Talent  Department  \
# 0       1         1           2      102292       5           2
# 1       1         1           2      100411       5           3
# 2       0         1           2      102304       5           5
# 3       0         1           4      102324       5           7
# 4       0         1           3      100619       5           7
#
#    active_months           Reason
# 0           59.0    Career Growth
# 1            4.0    Career Growth
# 2           26.0    Career Growth
# 3          126.0    Career Growth
# 4          126.0  Personal Reason

# %% [markdown]
# Building Classification

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
scaler = StandardScaler()
XS_train = scaler.fit_transform(X_train)
XS_test = scaler.transform(X_test)

# %%
model = KNeighborsClassifier()
model.fit(XS_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(XS_train, y_train)
# Out:
# 0.5103626943005182

# %%
def classification(df:pd.DataFrame, combo:list,  iteration=1):

    result = []
    for num in range(1, iteration+1):
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

        scaler = StandardScaler()
        XS_train = scaler.fit_transform(X_train)
        XS_test = scaler.transform(X_test)

        model = KNeighborsClassifier()
        model.fit(XS_train, y_train)

        train_score = round(model.score(XS_train, y_train) * 100, 2)
        test_score = round(model.score(XS_test, y_test) * 100, 2)

        stability = 100 - abs(train_score - test_score) 

        result.append([model, combo, train_score, test_score, stability])
    
    df_result = pd.DataFrame(result)
    df_result.columns = ['Model', 'combo', 'Train Score', 'Test Score', 'Stability']
    df_result = df_result.sort_values(by='Stability', ascending=False)

    return df_result

# %%
df['Reason'].unique()
# Out:
# array(['Career Growth', 'Personal Reason', 'Relocated to Other Branch',
#        'Salary Hike', 'Higher Studies', 'Relocation to Native',
#        'Internal Politics', 'Company Rules', 'Health Issues',
#        'Work Life Balance', 'Marriage', 'Not Suitable Job for the Skills',
#        'Miscellaneous', 'Family Problems', 'Not Interested in JOB',
#        'Work Stress'], dtype=object)

# %%
df['Reason'].nunique()
# Out:
# 16

# %%
def update_reason(value):

    if value in ['Salary Hike', 'Career Growth']:
        return value
    else:
        return 'OTH'

# %%
df.head()
# Out:
#    Gender  Location  Age Bucket  Manager ID  Talent  Department  \
# 0       1         1           2      102292       5           2
# 1       1         1           2      100411       5           3
# 2       0         1           2      102304       5           5
# 3       0         1           4      102324       5           7
# 4       0         1           3      100619       5           7
#
#    active_months           Reason
# 0           59.0    Career Growth
# 1            4.0    Career Growth
# 2           26.0    Career Growth
# 3          126.0    Career Growth
# 4          126.0  Personal Reason

# %%
# df['Reason'] = df['Reason'].apply(lambda x:update_reason(x))
# df['Reason'].unique()

# %%
classification(df, 100)
# Out:
#                     Model  combo  Train Score  Test Score  Stability
# 0  KNeighborsClassifier()    100        52.33       35.54      83.21

# %% [markdown]
# Create Combinations

# %%
reasons = df['Reason'].unique()
reasons
# Out:
# array(['Career Growth', 'Personal Reason', 'Relocated to Other Branch',
#        'Salary Hike', 'Higher Studies', 'Relocation to Native',
#        'Internal Politics', 'Company Rules', 'Health Issues',
#        'Work Life Balance', 'Marriage', 'Not Suitable Job for the Skills',
#        'Miscellaneous', 'Family Problems', 'Not Interested in JOB',
#        'Work Stress'], dtype=object)

# %%
combos = []
for num in range(1, len(reasons)+ 1):
    combo_list = list(combinations(reasons, num))
    combos.append(combo_list)

combos
# Out:
# [[('Career Growth',),
#   ('Personal Reason',),
#   ('Relocated to Other Branch',),
#   ('Salary Hike',),
#   ('Higher Studies',),
#   ('Relocation to Native',),
#   ('Internal Politics',),
#   ('Company Rules',),
#   ('Health Issues',),
#   ('Work Life Balance',),
#   ('Marriage',),
#   ('Not Suitable Job for the Skills',),
#   ('Miscellaneous',),
#   ('Family Problems',),
#   ('Not Interested in JOB',),
#   ('Work Stress',)],
#  [('Career Growth', 'Personal Reason'),
#   ('Career Growth', 'Relocated to Other Branch'),
#   ('Career Growth', 'Salary Hike'),
#   ('Career Growth', 'Higher Studies'),
#   ('Career Growth', 'Relocation to Native'),
#   ('Career Growth', 'Internal Politics'),
#   ('Career Growth', 'Company Rules'),
#   ('Career Growth', 'Health Issues'),
#   ('Career Growth', 'Work Life Balance'),
#   ('Career Growth', 'Marriage'),
#   ('Career Growth', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Miscellaneous'),
#   ('Career Growth', 'Family Problems'),
#   ('Career Growth', 'Not Interested in JOB'),
#   ('Career Growth', 'Work Stress'),
#   ('Personal Reason', 'Relocated to Other Branch'),
#   ('Personal Reason', 'Salary Hike'),
#   ('Personal Reason', 'Higher Studies'),
#   ('Personal Reason', 'Relocation to Native'),
#   ('Personal Reason', 'Internal Politics'),
#   ('Personal Reason', 'Company Rules'),
#   ('Personal Reason', 'Health Issues'),
#   ('Personal Reason', 'Work Life Balance'),
#   ('Personal Reason', 'Marriage'),
#   ('Personal Reason', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Miscellaneous'),
#   ('Personal Reason', 'Family Problems'),
#   ('Personal Reason', 'Not Interested in JOB'),
#   ('Personal Reason', 'Work Stress'),
#   ('Relocated to Other Branch', 'Salary Hike'),
#   ('Relocated to Other Branch', 'Higher Studies'),
#   ('Relocated to Other Branch', 'Relocation to Native'),
#   ('Relocated to Other Branch', 'Internal Politics'),
#   ('Relocated to Other Branch', 'Company Rules'),
#   ('Relocated to Other Branch', 'Health Issues'),
#   ('Relocated to Other Branch', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Marriage'),
#   ('Relocated to Other Branch', 'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Family Problems'),
#   ('Relocated to Other Branch', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Work Stress'),
#   ('Salary Hike', 'Higher Studies'),
#   ('Salary Hike', 'Relocation to Native'),
#   ('Salary Hike', 'Internal Politics'),
#   ('Salary Hike', 'Company Rules'),
#   ('Salary Hike', 'Health Issues'),
#   ('Salary Hike', 'Work Life Balance'),
#   ('Salary Hike', 'Marriage'),
#   ('Salary Hike', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Miscellaneous'),
#   ('Salary Hike', 'Family Problems'),
#   ('Salary Hike', 'Not Interested in JOB'),
#   ('Salary Hike', 'Work Stress'),
#   ('Higher Studies', 'Relocation to Native'),
#   ('Higher Studies', 'Internal Politics'),
#   ('Higher Studies', 'Company Rules'),
#   ('Higher Studies', 'Health Issues'),
#   ('Higher Studies', 'Work Life Balance'),
#   ('Higher Studies', 'Marriage'),
#   ('Higher Studies', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Miscellaneous'),
#   ('Higher Studies', 'Family Problems'),
#   ('Higher Studies', 'Not Interested in JOB'),
#   ('Higher Studies', 'Work Stress'),
#   ('Relocation to Native', 'Internal Politics'),
#   ('Relocation to Native', 'Company Rules'),
#   ('Relocation to Native', 'Health Issues'),
#   ('Relocation to Native', 'Work Life Balance'),
#   ('Relocation to Native', 'Marriage'),
#   ('Relocation to Native', 'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Miscellaneous'),
#   ('Relocation to Native', 'Family Problems'),
#   ('Relocation to Native', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Work Stress'),
#   ('Internal Politics', 'Company Rules'),
#   ('Internal Politics', 'Health Issues'),
#   ('Internal Politics', 'Work Life Balance'),
#   ('Internal Politics', 'Marriage'),
#   ('Internal Politics', 'Not Suitable Job for the Skills'),
#   ('Internal Politics', 'Miscellaneous'),
#   ('Internal Politics', 'Family Problems'),
#   ('Internal Politics', 'Not Interested in JOB'),
#   ('Internal Politics', 'Work Stress'),
#   ('Company Rules', 'Health Issues'),
#   ('Company Rules', 'Work Life Balance'),
#   ('Company Rules', 'Marriage'),
#   ('Company Rules', 'Not Suitable Job for the Skills'),
#   ('Company Rules', 'Miscellaneous'),
#   ('Company Rules', 'Family Problems'),
#   ('Company Rules', 'Not Interested in JOB'),
#   ('Company Rules', 'Work Stress'),
#   ('Health Issues', 'Work Life Balance'),
#   ('Health Issues', 'Marriage'),
#   ('Health Issues', 'Not Suitable Job for the Skills'),
#   ('Health Issues', 'Miscellaneous'),
#   ('Health Issues', 'Family Problems'),
#   ('Health Issues', 'Not Interested in JOB'),
#   ('Health Issues', 'Work Stress'),
#   ('Work Life Balance', 'Marriage'),
#   ('Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Work Life Balance', 'Miscellaneous'),
#   ('Work Life Balance', 'Family Problems'),
#   ('Work Life Balance', 'Not Interested in JOB'),
#   ('Work Life Balance', 'Work Stress'),
#   ('Marriage', 'Not Suitable Job for the Skills'),
#   ('Marriage', 'Miscellaneous'),
#   ('Marriage', 'Family Problems'),
#   ('Marriage', 'Not Interested in JOB'),
#   ('Marriage', 'Work Stress'),
#   ('Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Not Suitable Job for the Skills', 'Family Problems'),
#   ('Not Suitable Job for the Skills', 'Not Interested in JOB'),
#   ('Not Suitable Job for the Skills', 'Work Stress'),
#   ('Miscellaneous', 'Family Problems'),
#   ('Miscellaneous', 'Not Interested in JOB'),
#   ('Miscellaneous', 'Work Stress'),
#   ('Family Problems', 'Not Interested in JOB'),
#   ('Family Problems', 'Work Stress'),
#   ('Not Interested in JOB', 'Work Stress')],
#  [('Career Growth', 'Personal Reason', 'Relocated to Other Branch'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies'),
#   ('Career Growth', 'Personal Reason', 'Relocation to Native'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics'),
#   ('Career Growth', 'Personal Reason', 'Company Rules'),
#   ('Career Growth', 'Personal Reason', 'Health Issues'),
#   ('Career Growth', 'Personal Reason', 'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Marriage'),
#   ('Career Growth', 'Personal Reason', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Family Problems'),
#   ('Career Growth', 'Personal Reason', 'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Work Stress'),
#   ('Career Growth', 'Relocated to Other Branch', 'Salary Hike'),
#   ('Career Growth', 'Relocated to Other Branch', 'Higher Studies'),
#   ('Career Growth', 'Relocated to Other Branch', 'Relocation to Native'),
#   ('Career Growth', 'Relocated to Other Branch', 'Internal Politics'),
#   ('Career Growth', 'Relocated to Other Branch', 'Company Rules'),
#   ('Career Growth', 'Relocated to Other Branch', 'Health Issues'),
#   ('Career Growth', 'Relocated to Other Branch', 'Work Life Balance'),
#   ('Career Growth', 'Relocated to Other Branch', 'Marriage'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Relocated to Other Branch', 'Miscellaneous'),
#   ('Career Growth', 'Relocated to Other Branch', 'Family Problems'),
#   ('Career Growth', 'Relocated to Other Branch', 'Not Interested in JOB'),
#   ('Career Growth', 'Relocated to Other Branch', 'Work Stress'),
#   ('Career Growth', 'Salary Hike', 'Higher Studies'),
#   ('Career Growth', 'Salary Hike', 'Relocation to Native'),
#   ('Career Growth', 'Salary Hike', 'Internal Politics'),
#   ('Career Growth', 'Salary Hike', 'Company Rules'),
#   ('Career Growth', 'Salary Hike', 'Health Issues'),
#   ('Career Growth', 'Salary Hike', 'Work Life Balance'),
#   ('Career Growth', 'Salary Hike', 'Marriage'),
#   ('Career Growth', 'Salary Hike', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Salary Hike', 'Miscellaneous'),
#   ('Career Growth', 'Salary Hike', 'Family Problems'),
#   ('Career Growth', 'Salary Hike', 'Not Interested in JOB'),
#   ('Career Growth', 'Salary Hike', 'Work Stress'),
#   ('Career Growth', 'Higher Studies', 'Relocation to Native'),
#   ('Career Growth', 'Higher Studies', 'Internal Politics'),
#   ('Career Growth', 'Higher Studies', 'Company Rules'),
#   ('Career Growth', 'Higher Studies', 'Health Issues'),
#   ('Career Growth', 'Higher Studies', 'Work Life Balance'),
#   ('Career Growth', 'Higher Studies', 'Marriage'),
#   ('Career Growth', 'Higher Studies', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Higher Studies', 'Miscellaneous'),
#   ('Career Growth', 'Higher Studies', 'Family Problems'),
#   ('Career Growth', 'Higher Studies', 'Not Interested in JOB'),
#   ('Career Growth', 'Higher Studies', 'Work Stress'),
#   ('Career Growth', 'Relocation to Native', 'Internal Politics'),
#   ('Career Growth', 'Relocation to Native', 'Company Rules'),
#   ('Career Growth', 'Relocation to Native', 'Health Issues'),
#   ('Career Growth', 'Relocation to Native', 'Work Life Balance'),
#   ('Career Growth', 'Relocation to Native', 'Marriage'),
#   ('Career Growth', 'Relocation to Native', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Relocation to Native', 'Miscellaneous'),
#   ('Career Growth', 'Relocation to Native', 'Family Problems'),
#   ('Career Growth', 'Relocation to Native', 'Not Interested in JOB'),
#   ('Career Growth', 'Relocation to Native', 'Work Stress'),
#   ('Career Growth', 'Internal Politics', 'Company Rules'),
#   ('Career Growth', 'Internal Politics', 'Health Issues'),
#   ('Career Growth', 'Internal Politics', 'Work Life Balance'),
#   ('Career Growth', 'Internal Politics', 'Marriage'),
#   ('Career Growth', 'Internal Politics', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Internal Politics', 'Miscellaneous'),
#   ('Career Growth', 'Internal Politics', 'Family Problems'),
#   ('Career Growth', 'Internal Politics', 'Not Interested in JOB'),
#   ('Career Growth', 'Internal Politics', 'Work Stress'),
#   ('Career Growth', 'Company Rules', 'Health Issues'),
#   ('Career Growth', 'Company Rules', 'Work Life Balance'),
#   ('Career Growth', 'Company Rules', 'Marriage'),
#   ('Career Growth', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Company Rules', 'Miscellaneous'),
#   ('Career Growth', 'Company Rules', 'Family Problems'),
#   ('Career Growth', 'Company Rules', 'Not Interested in JOB'),
#   ('Career Growth', 'Company Rules', 'Work Stress'),
#   ('Career Growth', 'Health Issues', 'Work Life Balance'),
#   ('Career Growth', 'Health Issues', 'Marriage'),
#   ('Career Growth', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Health Issues', 'Miscellaneous'),
#   ('Career Growth', 'Health Issues', 'Family Problems'),
#   ('Career Growth', 'Health Issues', 'Not Interested in JOB'),
#   ('Career Growth', 'Health Issues', 'Work Stress'),
#   ('Career Growth', 'Work Life Balance', 'Marriage'),
#   ('Career Growth', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Work Life Balance', 'Miscellaneous'),
#   ('Career Growth', 'Work Life Balance', 'Family Problems'),
#   ('Career Growth', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Career Growth', 'Work Life Balance', 'Work Stress'),
#   ('Career Growth', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Marriage', 'Miscellaneous'),
#   ('Career Growth', 'Marriage', 'Family Problems'),
#   ('Career Growth', 'Marriage', 'Not Interested in JOB'),
#   ('Career Growth', 'Marriage', 'Work Stress'),
#   ('Career Growth', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Career Growth', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Career Growth',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Career Growth', 'Miscellaneous', 'Family Problems'),
#   ('Career Growth', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Career Growth', 'Miscellaneous', 'Work Stress'),
#   ('Career Growth', 'Family Problems', 'Not Interested in JOB'),
#   ('Career Growth', 'Family Problems', 'Work Stress'),
#   ('Career Growth', 'Not Interested in JOB', 'Work Stress'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Salary Hike'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Higher Studies'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Relocation to Native'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Internal Politics'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Company Rules'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Health Issues'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Work Life Balance'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Marriage'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Miscellaneous'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Family Problems'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Not Interested in JOB'),
#   ('Personal Reason', 'Relocated to Other Branch', 'Work Stress'),
#   ('Personal Reason', 'Salary Hike', 'Higher Studies'),
#   ('Personal Reason', 'Salary Hike', 'Relocation to Native'),
#   ('Personal Reason', 'Salary Hike', 'Internal Politics'),
#   ('Personal Reason', 'Salary Hike', 'Company Rules'),
#   ('Personal Reason', 'Salary Hike', 'Health Issues'),
#   ('Personal Reason', 'Salary Hike', 'Work Life Balance'),
#   ('Personal Reason', 'Salary Hike', 'Marriage'),
#   ('Personal Reason', 'Salary Hike', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Salary Hike', 'Miscellaneous'),
#   ('Personal Reason', 'Salary Hike', 'Family Problems'),
#   ('Personal Reason', 'Salary Hike', 'Not Interested in JOB'),
#   ('Personal Reason', 'Salary Hike', 'Work Stress'),
#   ('Personal Reason', 'Higher Studies', 'Relocation to Native'),
#   ('Personal Reason', 'Higher Studies', 'Internal Politics'),
#   ('Personal Reason', 'Higher Studies', 'Company Rules'),
#   ('Personal Reason', 'Higher Studies', 'Health Issues'),
#   ('Personal Reason', 'Higher Studies', 'Work Life Balance'),
#   ('Personal Reason', 'Higher Studies', 'Marriage'),
#   ('Personal Reason', 'Higher Studies', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Higher Studies', 'Miscellaneous'),
#   ('Personal Reason', 'Higher Studies', 'Family Problems'),
#   ('Personal Reason', 'Higher Studies', 'Not Interested in JOB'),
#   ('Personal Reason', 'Higher Studies', 'Work Stress'),
#   ('Personal Reason', 'Relocation to Native', 'Internal Politics'),
#   ('Personal Reason', 'Relocation to Native', 'Company Rules'),
#   ('Personal Reason', 'Relocation to Native', 'Health Issues'),
#   ('Personal Reason', 'Relocation to Native', 'Work Life Balance'),
#   ('Personal Reason', 'Relocation to Native', 'Marriage'),
#   ('Personal Reason',
#    'Relocation to Native',
#    'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Relocation to Native', 'Miscellaneous'),
#   ('Personal Reason', 'Relocation to Native', 'Family Problems'),
#   ('Personal Reason', 'Relocation to Native', 'Not Interested in JOB'),
#   ('Personal Reason', 'Relocation to Native', 'Work Stress'),
#   ('Personal Reason', 'Internal Politics', 'Company Rules'),
#   ('Personal Reason', 'Internal Politics', 'Health Issues'),
#   ('Personal Reason', 'Internal Politics', 'Work Life Balance'),
#   ('Personal Reason', 'Internal Politics', 'Marriage'),
#   ('Personal Reason', 'Internal Politics', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Internal Politics', 'Miscellaneous'),
#   ('Personal Reason', 'Internal Politics', 'Family Problems'),
#   ('Personal Reason', 'Internal Politics', 'Not Interested in JOB'),
#   ('Personal Reason', 'Internal Politics', 'Work Stress'),
#   ('Personal Reason', 'Company Rules', 'Health Issues'),
#   ('Personal Reason', 'Company Rules', 'Work Life Balance'),
#   ('Personal Reason', 'Company Rules', 'Marriage'),
#   ('Personal Reason', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Company Rules', 'Miscellaneous'),
#   ('Personal Reason', 'Company Rules', 'Family Problems'),
#   ('Personal Reason', 'Company Rules', 'Not Interested in JOB'),
#   ('Personal Reason', 'Company Rules', 'Work Stress'),
#   ('Personal Reason', 'Health Issues', 'Work Life Balance'),
#   ('Personal Reason', 'Health Issues', 'Marriage'),
#   ('Personal Reason', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Health Issues', 'Miscellaneous'),
#   ('Personal Reason', 'Health Issues', 'Family Problems'),
#   ('Personal Reason', 'Health Issues', 'Not Interested in JOB'),
#   ('Personal Reason', 'Health Issues', 'Work Stress'),
#   ('Personal Reason', 'Work Life Balance', 'Marriage'),
#   ('Personal Reason', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Work Life Balance', 'Miscellaneous'),
#   ('Personal Reason', 'Work Life Balance', 'Family Problems'),
#   ('Personal Reason', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Personal Reason', 'Work Life Balance', 'Work Stress'),
#   ('Personal Reason', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Personal Reason', 'Marriage', 'Miscellaneous'),
#   ('Personal Reason', 'Marriage', 'Family Problems'),
#   ('Personal Reason', 'Marriage', 'Not Interested in JOB'),
#   ('Personal Reason', 'Marriage', 'Work Stress'),
#   ('Personal Reason', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Personal Reason', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Personal Reason',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Personal Reason', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Personal Reason', 'Miscellaneous', 'Family Problems'),
#   ('Personal Reason', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Personal Reason', 'Miscellaneous', 'Work Stress'),
#   ('Personal Reason', 'Family Problems', 'Not Interested in JOB'),
#   ('Personal Reason', 'Family Problems', 'Work Stress'),
#   ('Personal Reason', 'Not Interested in JOB', 'Work Stress'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Higher Studies'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Relocation to Native'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Internal Politics'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Company Rules'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Health Issues'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Salary Hike',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Family Problems'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Salary Hike', 'Work Stress'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Relocation to Native'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Internal Politics'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Company Rules'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Health Issues'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Higher Studies',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Family Problems'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Higher Studies', 'Work Stress'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Internal Politics'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Company Rules'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Health Issues'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Relocation to Native',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Family Problems'),
#   ('Relocated to Other Branch',
#    'Relocation to Native',
#    'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Relocation to Native', 'Work Stress'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Company Rules'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Health Issues'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Internal Politics',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Family Problems'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Internal Politics', 'Work Stress'),
#   ('Relocated to Other Branch', 'Company Rules', 'Health Issues'),
#   ('Relocated to Other Branch', 'Company Rules', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Company Rules', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Company Rules',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Company Rules', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Company Rules', 'Family Problems'),
#   ('Relocated to Other Branch', 'Company Rules', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Company Rules', 'Work Stress'),
#   ('Relocated to Other Branch', 'Health Issues', 'Work Life Balance'),
#   ('Relocated to Other Branch', 'Health Issues', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Health Issues',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Health Issues', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Health Issues', 'Family Problems'),
#   ('Relocated to Other Branch', 'Health Issues', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Health Issues', 'Work Stress'),
#   ('Relocated to Other Branch', 'Work Life Balance', 'Marriage'),
#   ('Relocated to Other Branch',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Work Life Balance', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Work Life Balance', 'Family Problems'),
#   ('Relocated to Other Branch', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Work Life Balance', 'Work Stress'),
#   ('Relocated to Other Branch', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Relocated to Other Branch', 'Marriage', 'Miscellaneous'),
#   ('Relocated to Other Branch', 'Marriage', 'Family Problems'),
#   ('Relocated to Other Branch', 'Marriage', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Marriage', 'Work Stress'),
#   ('Relocated to Other Branch',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous'),
#   ('Relocated to Other Branch',
#    'Not Suitable Job for the Skills',
#    'Family Problems'),
#   ('Relocated to Other Branch',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Relocated to Other Branch',
#    'Not Suitable Job for the Skills',
#    'Work Stress'),
#   ('Relocated to Other Branch', 'Miscellaneous', 'Family Problems'),
#   ('Relocated to Other Branch', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Miscellaneous', 'Work Stress'),
#   ('Relocated to Other Branch', 'Family Problems', 'Not Interested in JOB'),
#   ('Relocated to Other Branch', 'Family Problems', 'Work Stress'),
#   ('Relocated to Other Branch', 'Not Interested in JOB', 'Work Stress'),
#   ('Salary Hike', 'Higher Studies', 'Relocation to Native'),
#   ('Salary Hike', 'Higher Studies', 'Internal Politics'),
#   ('Salary Hike', 'Higher Studies', 'Company Rules'),
#   ('Salary Hike', 'Higher Studies', 'Health Issues'),
#   ('Salary Hike', 'Higher Studies', 'Work Life Balance'),
#   ('Salary Hike', 'Higher Studies', 'Marriage'),
#   ('Salary Hike', 'Higher Studies', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Higher Studies', 'Miscellaneous'),
#   ('Salary Hike', 'Higher Studies', 'Family Problems'),
#   ('Salary Hike', 'Higher Studies', 'Not Interested in JOB'),
#   ('Salary Hike', 'Higher Studies', 'Work Stress'),
#   ('Salary Hike', 'Relocation to Native', 'Internal Politics'),
#   ('Salary Hike', 'Relocation to Native', 'Company Rules'),
#   ('Salary Hike', 'Relocation to Native', 'Health Issues'),
#   ('Salary Hike', 'Relocation to Native', 'Work Life Balance'),
#   ('Salary Hike', 'Relocation to Native', 'Marriage'),
#   ('Salary Hike', 'Relocation to Native', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Relocation to Native', 'Miscellaneous'),
#   ('Salary Hike', 'Relocation to Native', 'Family Problems'),
#   ('Salary Hike', 'Relocation to Native', 'Not Interested in JOB'),
#   ('Salary Hike', 'Relocation to Native', 'Work Stress'),
#   ('Salary Hike', 'Internal Politics', 'Company Rules'),
#   ('Salary Hike', 'Internal Politics', 'Health Issues'),
#   ('Salary Hike', 'Internal Politics', 'Work Life Balance'),
#   ('Salary Hike', 'Internal Politics', 'Marriage'),
#   ('Salary Hike', 'Internal Politics', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Internal Politics', 'Miscellaneous'),
#   ('Salary Hike', 'Internal Politics', 'Family Problems'),
#   ('Salary Hike', 'Internal Politics', 'Not Interested in JOB'),
#   ('Salary Hike', 'Internal Politics', 'Work Stress'),
#   ('Salary Hike', 'Company Rules', 'Health Issues'),
#   ('Salary Hike', 'Company Rules', 'Work Life Balance'),
#   ('Salary Hike', 'Company Rules', 'Marriage'),
#   ('Salary Hike', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Company Rules', 'Miscellaneous'),
#   ('Salary Hike', 'Company Rules', 'Family Problems'),
#   ('Salary Hike', 'Company Rules', 'Not Interested in JOB'),
#   ('Salary Hike', 'Company Rules', 'Work Stress'),
#   ('Salary Hike', 'Health Issues', 'Work Life Balance'),
#   ('Salary Hike', 'Health Issues', 'Marriage'),
#   ('Salary Hike', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Health Issues', 'Miscellaneous'),
#   ('Salary Hike', 'Health Issues', 'Family Problems'),
#   ('Salary Hike', 'Health Issues', 'Not Interested in JOB'),
#   ('Salary Hike', 'Health Issues', 'Work Stress'),
#   ('Salary Hike', 'Work Life Balance', 'Marriage'),
#   ('Salary Hike', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Work Life Balance', 'Miscellaneous'),
#   ('Salary Hike', 'Work Life Balance', 'Family Problems'),
#   ('Salary Hike', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Salary Hike', 'Work Life Balance', 'Work Stress'),
#   ('Salary Hike', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Salary Hike', 'Marriage', 'Miscellaneous'),
#   ('Salary Hike', 'Marriage', 'Family Problems'),
#   ('Salary Hike', 'Marriage', 'Not Interested in JOB'),
#   ('Salary Hike', 'Marriage', 'Work Stress'),
#   ('Salary Hike', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Salary Hike', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Salary Hike', 'Not Suitable Job for the Skills', 'Not Interested in JOB'),
#   ('Salary Hike', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Salary Hike', 'Miscellaneous', 'Family Problems'),
#   ('Salary Hike', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Salary Hike', 'Miscellaneous', 'Work Stress'),
#   ('Salary Hike', 'Family Problems', 'Not Interested in JOB'),
#   ('Salary Hike', 'Family Problems', 'Work Stress'),
#   ('Salary Hike', 'Not Interested in JOB', 'Work Stress'),
#   ('Higher Studies', 'Relocation to Native', 'Internal Politics'),
#   ('Higher Studies', 'Relocation to Native', 'Company Rules'),
#   ('Higher Studies', 'Relocation to Native', 'Health Issues'),
#   ('Higher Studies', 'Relocation to Native', 'Work Life Balance'),
#   ('Higher Studies', 'Relocation to Native', 'Marriage'),
#   ('Higher Studies',
#    'Relocation to Native',
#    'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Relocation to Native', 'Miscellaneous'),
#   ('Higher Studies', 'Relocation to Native', 'Family Problems'),
#   ('Higher Studies', 'Relocation to Native', 'Not Interested in JOB'),
#   ('Higher Studies', 'Relocation to Native', 'Work Stress'),
#   ('Higher Studies', 'Internal Politics', 'Company Rules'),
#   ('Higher Studies', 'Internal Politics', 'Health Issues'),
#   ('Higher Studies', 'Internal Politics', 'Work Life Balance'),
#   ('Higher Studies', 'Internal Politics', 'Marriage'),
#   ('Higher Studies', 'Internal Politics', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Internal Politics', 'Miscellaneous'),
#   ('Higher Studies', 'Internal Politics', 'Family Problems'),
#   ('Higher Studies', 'Internal Politics', 'Not Interested in JOB'),
#   ('Higher Studies', 'Internal Politics', 'Work Stress'),
#   ('Higher Studies', 'Company Rules', 'Health Issues'),
#   ('Higher Studies', 'Company Rules', 'Work Life Balance'),
#   ('Higher Studies', 'Company Rules', 'Marriage'),
#   ('Higher Studies', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Company Rules', 'Miscellaneous'),
#   ('Higher Studies', 'Company Rules', 'Family Problems'),
#   ('Higher Studies', 'Company Rules', 'Not Interested in JOB'),
#   ('Higher Studies', 'Company Rules', 'Work Stress'),
#   ('Higher Studies', 'Health Issues', 'Work Life Balance'),
#   ('Higher Studies', 'Health Issues', 'Marriage'),
#   ('Higher Studies', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Health Issues', 'Miscellaneous'),
#   ('Higher Studies', 'Health Issues', 'Family Problems'),
#   ('Higher Studies', 'Health Issues', 'Not Interested in JOB'),
#   ('Higher Studies', 'Health Issues', 'Work Stress'),
#   ('Higher Studies', 'Work Life Balance', 'Marriage'),
#   ('Higher Studies', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Work Life Balance', 'Miscellaneous'),
#   ('Higher Studies', 'Work Life Balance', 'Family Problems'),
#   ('Higher Studies', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Higher Studies', 'Work Life Balance', 'Work Stress'),
#   ('Higher Studies', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Higher Studies', 'Marriage', 'Miscellaneous'),
#   ('Higher Studies', 'Marriage', 'Family Problems'),
#   ('Higher Studies', 'Marriage', 'Not Interested in JOB'),
#   ('Higher Studies', 'Marriage', 'Work Stress'),
#   ('Higher Studies', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Higher Studies', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Higher Studies',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Higher Studies', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Higher Studies', 'Miscellaneous', 'Family Problems'),
#   ('Higher Studies', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Higher Studies', 'Miscellaneous', 'Work Stress'),
#   ('Higher Studies', 'Family Problems', 'Not Interested in JOB'),
#   ('Higher Studies', 'Family Problems', 'Work Stress'),
#   ('Higher Studies', 'Not Interested in JOB', 'Work Stress'),
#   ('Relocation to Native', 'Internal Politics', 'Company Rules'),
#   ('Relocation to Native', 'Internal Politics', 'Health Issues'),
#   ('Relocation to Native', 'Internal Politics', 'Work Life Balance'),
#   ('Relocation to Native', 'Internal Politics', 'Marriage'),
#   ('Relocation to Native',
#    'Internal Politics',
#    'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Internal Politics', 'Miscellaneous'),
#   ('Relocation to Native', 'Internal Politics', 'Family Problems'),
#   ('Relocation to Native', 'Internal Politics', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Internal Politics', 'Work Stress'),
#   ('Relocation to Native', 'Company Rules', 'Health Issues'),
#   ('Relocation to Native', 'Company Rules', 'Work Life Balance'),
#   ('Relocation to Native', 'Company Rules', 'Marriage'),
#   ('Relocation to Native', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Company Rules', 'Miscellaneous'),
#   ('Relocation to Native', 'Company Rules', 'Family Problems'),
#   ('Relocation to Native', 'Company Rules', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Company Rules', 'Work Stress'),
#   ('Relocation to Native', 'Health Issues', 'Work Life Balance'),
#   ('Relocation to Native', 'Health Issues', 'Marriage'),
#   ('Relocation to Native', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Health Issues', 'Miscellaneous'),
#   ('Relocation to Native', 'Health Issues', 'Family Problems'),
#   ('Relocation to Native', 'Health Issues', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Health Issues', 'Work Stress'),
#   ('Relocation to Native', 'Work Life Balance', 'Marriage'),
#   ('Relocation to Native',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Work Life Balance', 'Miscellaneous'),
#   ('Relocation to Native', 'Work Life Balance', 'Family Problems'),
#   ('Relocation to Native', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Work Life Balance', 'Work Stress'),
#   ('Relocation to Native', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Relocation to Native', 'Marriage', 'Miscellaneous'),
#   ('Relocation to Native', 'Marriage', 'Family Problems'),
#   ('Relocation to Native', 'Marriage', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Marriage', 'Work Stress'),
#   ('Relocation to Native', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Relocation to Native',
#    'Not Suitable Job for the Skills',
#    'Family Problems'),
#   ('Relocation to Native',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Relocation to Native', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Relocation to Native', 'Miscellaneous', 'Family Problems'),
#   ('Relocation to Native', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Miscellaneous', 'Work Stress'),
#   ('Relocation to Native', 'Family Problems', 'Not Interested in JOB'),
#   ('Relocation to Native', 'Family Problems', 'Work Stress'),
#   ('Relocation to Native', 'Not Interested in JOB', 'Work Stress'),
#   ('Internal Politics', 'Company Rules', 'Health Issues'),
#   ('Internal Politics', 'Company Rules', 'Work Life Balance'),
#   ('Internal Politics', 'Company Rules', 'Marriage'),
#   ('Internal Politics', 'Company Rules', 'Not Suitable Job for the Skills'),
#   ('Internal Politics', 'Company Rules', 'Miscellaneous'),
#   ('Internal Politics', 'Company Rules', 'Family Problems'),
#   ('Internal Politics', 'Company Rules', 'Not Interested in JOB'),
#   ('Internal Politics', 'Company Rules', 'Work Stress'),
#   ('Internal Politics', 'Health Issues', 'Work Life Balance'),
#   ('Internal Politics', 'Health Issues', 'Marriage'),
#   ('Internal Politics', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Internal Politics', 'Health Issues', 'Miscellaneous'),
#   ('Internal Politics', 'Health Issues', 'Family Problems'),
#   ('Internal Politics', 'Health Issues', 'Not Interested in JOB'),
#   ('Internal Politics', 'Health Issues', 'Work Stress'),
#   ('Internal Politics', 'Work Life Balance', 'Marriage'),
#   ('Internal Politics',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills'),
#   ('Internal Politics', 'Work Life Balance', 'Miscellaneous'),
#   ('Internal Politics', 'Work Life Balance', 'Family Problems'),
#   ('Internal Politics', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Internal Politics', 'Work Life Balance', 'Work Stress'),
#   ('Internal Politics', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Internal Politics', 'Marriage', 'Miscellaneous'),
#   ('Internal Politics', 'Marriage', 'Family Problems'),
#   ('Internal Politics', 'Marriage', 'Not Interested in JOB'),
#   ('Internal Politics', 'Marriage', 'Work Stress'),
#   ('Internal Politics', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Internal Politics', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Internal Politics',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Internal Politics', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Internal Politics', 'Miscellaneous', 'Family Problems'),
#   ('Internal Politics', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Internal Politics', 'Miscellaneous', 'Work Stress'),
#   ('Internal Politics', 'Family Problems', 'Not Interested in JOB'),
#   ('Internal Politics', 'Family Problems', 'Work Stress'),
#   ('Internal Politics', 'Not Interested in JOB', 'Work Stress'),
#   ('Company Rules', 'Health Issues', 'Work Life Balance'),
#   ('Company Rules', 'Health Issues', 'Marriage'),
#   ('Company Rules', 'Health Issues', 'Not Suitable Job for the Skills'),
#   ('Company Rules', 'Health Issues', 'Miscellaneous'),
#   ('Company Rules', 'Health Issues', 'Family Problems'),
#   ('Company Rules', 'Health Issues', 'Not Interested in JOB'),
#   ('Company Rules', 'Health Issues', 'Work Stress'),
#   ('Company Rules', 'Work Life Balance', 'Marriage'),
#   ('Company Rules', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Company Rules', 'Work Life Balance', 'Miscellaneous'),
#   ('Company Rules', 'Work Life Balance', 'Family Problems'),
#   ('Company Rules', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Company Rules', 'Work Life Balance', 'Work Stress'),
#   ('Company Rules', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Company Rules', 'Marriage', 'Miscellaneous'),
#   ('Company Rules', 'Marriage', 'Family Problems'),
#   ('Company Rules', 'Marriage', 'Not Interested in JOB'),
#   ('Company Rules', 'Marriage', 'Work Stress'),
#   ('Company Rules', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Company Rules', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Company Rules',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Company Rules', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Company Rules', 'Miscellaneous', 'Family Problems'),
#   ('Company Rules', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Company Rules', 'Miscellaneous', 'Work Stress'),
#   ('Company Rules', 'Family Problems', 'Not Interested in JOB'),
#   ('Company Rules', 'Family Problems', 'Work Stress'),
#   ('Company Rules', 'Not Interested in JOB', 'Work Stress'),
#   ('Health Issues', 'Work Life Balance', 'Marriage'),
#   ('Health Issues', 'Work Life Balance', 'Not Suitable Job for the Skills'),
#   ('Health Issues', 'Work Life Balance', 'Miscellaneous'),
#   ('Health Issues', 'Work Life Balance', 'Family Problems'),
#   ('Health Issues', 'Work Life Balance', 'Not Interested in JOB'),
#   ('Health Issues', 'Work Life Balance', 'Work Stress'),
#   ('Health Issues', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Health Issues', 'Marriage', 'Miscellaneous'),
#   ('Health Issues', 'Marriage', 'Family Problems'),
#   ('Health Issues', 'Marriage', 'Not Interested in JOB'),
#   ('Health Issues', 'Marriage', 'Work Stress'),
#   ('Health Issues', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Health Issues', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Health Issues',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Health Issues', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Health Issues', 'Miscellaneous', 'Family Problems'),
#   ('Health Issues', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Health Issues', 'Miscellaneous', 'Work Stress'),
#   ('Health Issues', 'Family Problems', 'Not Interested in JOB'),
#   ('Health Issues', 'Family Problems', 'Work Stress'),
#   ('Health Issues', 'Not Interested in JOB', 'Work Stress'),
#   ('Work Life Balance', 'Marriage', 'Not Suitable Job for the Skills'),
#   ('Work Life Balance', 'Marriage', 'Miscellaneous'),
#   ('Work Life Balance', 'Marriage', 'Family Problems'),
#   ('Work Life Balance', 'Marriage', 'Not Interested in JOB'),
#   ('Work Life Balance', 'Marriage', 'Work Stress'),
#   ('Work Life Balance', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Work Life Balance', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Work Life Balance',
#    'Not Suitable Job for the Skills',
#    'Not Interested in JOB'),
#   ('Work Life Balance', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Work Life Balance', 'Miscellaneous', 'Family Problems'),
#   ('Work Life Balance', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Work Life Balance', 'Miscellaneous', 'Work Stress'),
#   ('Work Life Balance', 'Family Problems', 'Not Interested in JOB'),
#   ('Work Life Balance', 'Family Problems', 'Work Stress'),
#   ('Work Life Balance', 'Not Interested in JOB', 'Work Stress'),
#   ('Marriage', 'Not Suitable Job for the Skills', 'Miscellaneous'),
#   ('Marriage', 'Not Suitable Job for the Skills', 'Family Problems'),
#   ('Marriage', 'Not Suitable Job for the Skills', 'Not Interested in JOB'),
#   ('Marriage', 'Not Suitable Job for the Skills', 'Work Stress'),
#   ('Marriage', 'Miscellaneous', 'Family Problems'),
#   ('Marriage', 'Miscellaneous', 'Not Interested in JOB'),
#   ('Marriage', 'Miscellaneous', 'Work Stress'),
#   ('Marriage', 'Family Problems', 'Not Interested in JOB'),
#   ('Marriage', 'Family Problems', 'Work Stress'),
#   ('Marriage', 'Not Interested in JOB', 'Work Stress'),
#   ('Not Suitable Job for the Skills', 'Miscellaneous', 'Family Problems'),
#   ('Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Not Interested in JOB'),
#   ('Not Suitable Job for the Skills', 'Miscellaneous', 'Work Stress'),
#   ('Not Suitable Job for the Skills',
#    'Family Problems',
#    'Not Interested in JOB'),
#   ('Not Suitable Job for the Skills', 'Family Problems', 'Work Stress'),
#   ('Not Suitable Job for the Skills', 'Not Interested in JOB', 'Work Stress'),
#   ('Miscellaneous', 'Family Problems', 'Not Interested in JOB'),
#   ('Miscellaneous', 'Family Problems', 'Work Stress'),
#   ('Miscellaneous', 'Not Interested in JOB', 'Work Stress'),
#   ('Family Problems', 'Not Interested in JOB', 'Work Stress')],
#  [('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Higher Studies'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Relocation to Native'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Internal Politics'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Company Rules'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Health Issues'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Work Life Balance'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Miscellaneous'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Not Interested in JOB'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Work Stress'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Higher Studies'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Relocation to Native'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Internal Politics'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Company Rules'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Health Issues'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Salary Hike',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Family Problems'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Salary Hike', 'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Higher Studies',
#    'Relocation to Native'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Internal Politics'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Company Rules'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Health Issues'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Higher Studies',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Higher Studies',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Higher Studies', 'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Internal Politics'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Company Rules'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Health Issues'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Relocation to Native', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Miscellaneous'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocation to Native',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Relocation to Native', 'Work Stress'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Company Rules'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Health Issues'),
#   ('Career Growth',
#    'Personal Reason',
#    'Internal Politics',
#    'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Internal Politics',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Internal Politics',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Internal Politics', 'Work Stress'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Health Issues'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Company Rules',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Company Rules',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Company Rules', 'Work Stress'),
#   ('Career Growth', 'Personal Reason', 'Health Issues', 'Work Life Balance'),
#   ('Career Growth', 'Personal Reason', 'Health Issues', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Health Issues',
#    'Not Suitable Job for the Skills'),
#   ('Career Growth', 'Personal Reason', 'Health Issues', 'Miscellaneous'),
#   ('Career Growth', 'Personal Reason', 'Health Issues', 'Family Problems'),
#   ('Career Growth',
#    'Personal Reason',
#    'Health Issues',
#    'Not Interested in JOB'),
#   ('Career Growth', 'Personal Reason', 'Health Issues', 'Work Stress'),
#   ('Career Growth', 'Personal Reason', 'Work Life Balance', 'Marriage'),
#   ('Career Growth',
#    'Personal Reason',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills'),
# ...
#    'Personal Reason',
#    'Salary Hike',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress')],
#  [('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Personal Reason',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Career Growth',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress'),
#   ('Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress')],
#  [('Career Growth',
#    'Personal Reason',
#    'Relocated to Other Branch',
#    'Salary Hike',
#    'Higher Studies',
#    'Relocation to Native',
#    'Internal Politics',
#    'Company Rules',
#    'Health Issues',
#    'Work Life Balance',
#    'Marriage',
#    'Not Suitable Job for the Skills',
#    'Miscellaneous',
#    'Family Problems',
#    'Not Interested in JOB',
#    'Work Stress')]]

# %%
result = []
for subcombo in combos:
    for combo in subcombo:
        
        def update_reason(value):

            if value in combo:
                return value
            else:
                return 'OTH'
            
        df_process = df.copy()
        df_process['Reason'] = df_process['Reason'].apply(lambda x:update_reason(x))
        df_process['Reason'].unique()

        df_result = classification(df_process, combo)
        result.append(df_result)
    
    
            
df_final = pd.concat(result)
df_final.sort_values(by=['Test Score', 'Stability'], ascending=False)
df_final.head()
# Out:
#                     Model                         combo  Train Score  \
# 0  KNeighborsClassifier()              (Career Growth,)        74.61
# 0  KNeighborsClassifier()            (Personal Reason,)        78.50
# 0  KNeighborsClassifier()  (Relocated to Other Branch,)        99.74
# 0  KNeighborsClassifier()                (Salary Hike,)        86.53
# 0  KNeighborsClassifier()             (Higher Studies,)        92.75
#
#    Test Score  Stability
# 0       57.23      82.62
# 0       81.93      96.57
# 0       98.19      98.45
# 0       84.94      98.41
# 0       86.14      93.39
