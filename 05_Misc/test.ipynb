# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../00_Data/05_Encoded.csv')
df.head()
# Out:
#    Gender  Generation  Term Sub Reason  Employee Grade  Location  \
# 0       1           2                1               1         1
# 1       1           2                1               2         1
# 2       0           2                1               1         1
# 3       0           3                1               3         1
# 4       0           2               11               2         1
#
#    Career Bucket  Age Bucket  Manager ID  Talent  Department  active_months
# 0              1           2      102292       5           2           59.0
# 1              2           2      100411       5           3            4.0
# 2              1           2      102304       5           5           26.0
# 3              3           4      102324       5           7          126.0
# 4              2           3      100619       5           7          126.0

# %%
df.corr()
# Out:
#                    Gender  Generation  Term Sub Reason  Employee Grade  \
# Gender           1.000000   -0.149842         0.033417       -0.200803
# Generation      -0.149842    1.000000        -0.055130        0.549408
# Term Sub Reason  0.033417   -0.055130         1.000000        0.006829
# Employee Grade  -0.200803    0.549408         0.006829        1.000000
# Location        -0.003489    0.140014         0.039559        0.150103
# Career Bucket   -0.210521    0.630082         0.069867        0.614825
# Age Bucket      -0.224553    0.730424        -0.000087        0.667097
# Manager ID      -0.113509    0.228620        -0.072316        0.257182
# Talent           0.036671    0.009607        -0.063602       -0.067357
# Department       0.013234   -0.013846         0.159124       -0.007573
# active_months   -0.152648    0.392979        -0.061919        0.330834
#
#                  Location  Career Bucket  Age Bucket  Manager ID    Talent  \
# Gender          -0.003489      -0.210521   -0.224553   -0.113509  0.036671
# Generation       0.140014       0.630082    0.730424    0.228620  0.009607
# Term Sub Reason  0.039559       0.069867   -0.000087   -0.072316 -0.063602
# Employee Grade   0.150103       0.614825    0.667097    0.257182 -0.067357
# Location         1.000000       0.107519    0.158317    0.211256  0.038011
# Career Bucket    0.107519       1.000000    0.797834    0.191095 -0.108379
# Age Bucket       0.158317       0.797834    1.000000    0.241635 -0.016801
# Manager ID       0.211256       0.191095    0.241635    1.000000 -0.029755
# Talent           0.038011      -0.108379   -0.016801   -0.029755  1.000000
# Department       0.091034       0.144946    0.035399    0.285030 -0.062400
# active_months    0.103490       0.392599    0.469295    0.209606  0.012562
#
#                  Department  active_months
# Gender             0.013234      -0.152648
# Generation        -0.013846       0.392979
# Term Sub Reason    0.159124      -0.061919
# Employee Grade    -0.007573       0.330834
# Location           0.091034       0.103490
# Career Bucket      0.144946       0.392599
# Age Bucket         0.035399       0.469295
# Manager ID         0.285030       0.209606
# Talent            -0.062400       0.012562
# Department         1.000000       0.047426
# active_months      0.047426       1.000000

# %%
fig = plt.figure(figsize=(9, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1)
plt.show()
